# %%
import pandas as pd

# %%
sf=pd.read_csv("C:/Users/Localadmin/Downloads/Sf_Salaries.csv")
# Out:
# C:\Users\Localadmin\AppData\Local\Temp\ipykernel_10432\1312075873.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf=pd.read_csv("C:/Users/Localadmin/Downloads/Sf_Salaries.csv")

# %%
sf
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
x=sf[sf['JobTitle']=='Not provided']

# %%
x
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148650  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148651  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148652  Not Provided  Not Provided       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN

# %%
sf.drop({148646, 148650, 148651, 148652}, inplace=True)

# %%
sf
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148650 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 15.9+ MB

# %%
sf.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148650.000000  148650.000000     148650.000000  148650.000000    0.0
# mean    74325.500047   74770.333901      93695.075969    2012.522603    NaN
# std     42911.703176   50516.196009      62792.497391       1.117526    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37163.250000   36169.955000      44073.337500    2012.000000    NaN
# 50%     74325.500000   71427.240000      92406.020000    2013.000000    NaN
# 75%    111487.750000  105842.960000     132877.992500    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
sf[["BasePay","OvertimePay","OtherPay","Benefits"]]=sf[["BasePay","OvertimePay","OtherPay","Benefits"]].astype(float)

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148650 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 15.9+ MB

# %%
average_BasePay=sf['BasePay'].mean()
print("average BasePay:",average_BasePay )
# Out:
# average BasePay: 66325.4488404877

# %%
Max_overtime=sf['OvertimePay'].max()
print(Max_overtime)
# Out:
# 245131.88

# %%
y=sf[sf['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']

# %%
y
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sf[sf['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sf[sf['TotalPayBenefits']== sf['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
sf[sf['TotalPayBenefits']== sf['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency Status
# 148653  San Francisco     PT

# %%
sf.groupby('Year').mean()['BasePay']
# Out:
# C:\Users\Localadmin\AppData\Local\Temp\ipykernel_10432\3918708816.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sf.groupby('Year').mean()['BasePay']
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sf['JobTitle'].nunique()
# Out:
# 2158

# %%
sf['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
